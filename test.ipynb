# %%
import numpy as np
import pandas as pd

# %%
file ="/var/www/html/brief11_marché_travail_tech/france_travail.csv"

# %%
df = pd.read_csv(file, delimiter = ",",encoding='utf-8')
# Out:
# /tmp/ipykernel_61053/1754498073.py:1: DtypeWarning: Columns (51,53,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, delimiter = ",",encoding='utf-8')

# %%
df.head()
# Out:
#         id                                           intitule  \
# 0  3244435                            jardinier H/F - EC21126
# 1  3244427  agent développement social référent famille H/...
# 2  3244363  chargé mission renouvellement urbain H/F - EC2...
# 3  3244340                  médecin généraliste H/F - EC20779
# 4  3244304          responsable administratif ve H/F - EC9293
#
#                                          description  \
# 0  jardinier H/F - EC21126 Sous la responsabilité...
# 1  agent développement social référent famille H/...
# 2  chargé mission renouvellement urbain H/F - EC2...
# 3  médecin généraliste H/F - EC20779 UNIQUE en so...
# 4  responsable administratif ve H/F - EC9293 Miss...
#
#                dateCreation         dateActualisation  \
# 0  2024-09-01T02:51:53.000Z  2024-11-03T02:38:11.000Z
# 1  2024-09-01T02:51:30.000Z  2024-11-03T02:38:16.000Z
# 2  2024-09-01T02:49:40.000Z  2024-11-01T02:54:16.000Z
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458113 entries, 0 to 458112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            458113 non-null  object
#  1   intitule                      458113 non-null  object
#  2   description                   458113 non-null  object
#  3   dateCreation                  458113 non-null  object
#  4   dateActualisation             458113 non-null  object
#  5   lieuTravail_libelle           458113 non-null  object
#  6   lieuTravail_latitude          408832 non-null  float64
#  7   lieuTravail_longitude         408832 non-null  float64
#  8   lieuTravail_codePostal        404396 non-null  float64
#  9   lieuTravail_commune           407240 non-null  object
#  10  romeCode                      458113 non-null  object
#  11  romeLibelle                   458113 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'intitule', 'description', 'dateCreation', 'dateActualisation',
#        'lieuTravail_libelle', 'lieuTravail_latitude', 'lieuTravail_longitude',
#        'lieuTravail_codePostal', 'lieuTravail_commune', 'romeCode',
#        'romeLibelle', 'appellationlibelle', 'entreprise_nom',
#        'entreprise_entrepriseAdaptee', 'typeContrat', 'typeContratLibelle',
#        'natureContrat', 'experienceExige', 'experienceLibelle', 'alternance',
#        'nombrePostes', 'accessibleTH', 'origineOffre_origine',
#        'origineOffre_urlOrigine', 'origineOffre_partenaires',
#        'entreprise_description', 'dureeTravailLibelle',
#        'dureeTravailLibelleConverti', 'codeNAF', 'secteurActivite',
#        'secteurActiviteLibelle', 'salaire_libelle', 'salaire_commentaire',
#        'qualificationCode', 'qualificationLibelle', 'permis', 'competences',
#        'salaire_complement1', 'salaire_complement2',
#        'qualitesProfessionnelles', 'formations', 'contact_nom',
# ...

# %%
new_df = pd.concat([df['id'], df['intitule'], df['description']], axis=1)
nd = pd.DataFrame(new_df)
nd
# Out:
#              id                                           intitule  \
# 0       3244435                            jardinier H/F - EC21126
# 1       3244427  agent développement social référent famille H/...
# 2       3244363  chargé mission renouvellement urbain H/F - EC2...
# 3       3244340                  médecin généraliste H/F - EC20779
# 4       3244304          responsable administratif ve H/F - EC9293
# ...         ...                                                ...
# 458108  7103130                     Aide Auxiliaire H/F diplômé(e)
# 458109  7103129                       Responsable informatique H/F
# 458110  7103128                   CAP PETITE ENFANCE H/F en crèche
# 458111  7103127  Electromécanicien de maintenance industrielle H/F
# 458112  7103121                       Responsable informatique H/F
#
#                                               description
# 0       jardinier H/F - EC21126 Sous la responsabilité...
# ...

# %%
df['contact_urlPostulation'].value_counts()
# Out:
# contact_urlPostulation
# https://www1.ac-grenoble.fr/article/handicap-et-emploi-boe-rqth-121587                                                                        70
# https://www.acadomia.fr/enseignant.html#formulaire                                                                                            52
# https://www.police-nationale.interieur.gouv.fr/nous-rejoindre/inscriptions-aux-concours-et-selections/policier-adjoint-ouest-sessions-2024    39
# https://www.jehann.fr/recrutement                                                                                                             33
# https://chelles.candidater.fr/                                                                                                                25
#                                                                                                                                               ..
# ...

# %%
# 458 113 
df['entreprise_nom'].isnull().sum()
# Out:
# np.int64(152143)

# %%
df.isnull().sum()
# Out:
# id                                   0
# intitule                             0
# description                          0
# dateCreation                         0
# dateActualisation                    0
# lieuTravail_libelle                  0
# lieuTravail_latitude             49281
# lieuTravail_longitude            49281
# lieuTravail_codePostal           53717
# lieuTravail_commune              50873
# romeCode                             0
# romeLibelle                          0
# appellationlibelle                   0
# entreprise_nom                  152143
# entreprise_entrepriseAdaptee         0
# typeContrat                          0
# typeContratLibelle                   0
# natureContrat                        0
# experienceExige                      0
# experienceLibelle                    0
# alternance                           0
# nombrePostes                         0
# accessibleTH                         0
# origineOffre_origine                 0
# ...

# %%
rom = ('M1825', 'M1403')
m18 = df.loc[df['romeCode'].str.startswith(rom)]
m18
# Out:
#              id                                           intitule  \
# 380     3317313  Chargé(e)  du support  - Infrastructures des D...
# 578     3317313  Chargé(e)  du support  - Infrastructures des D...
# 766     3317313  Chargé(e)  du support  - Infrastructures des D...
# 900     3338741                             Analyste pricing (H/F)
# 2464    3479788       Chargé / Chargée d'études en marketing (H/F)
# ...         ...                                                ...
# 451227  7096289                       Ingénieur d'Etudes VRD (H/F)
# 451237  7096253                          Chargé d'études VRD (H/F)
# 451430  7096415              Ingénieur d'études CVC confirmé (H/F)
# 451436  7096397      Ingénieur d'Etudes Aménagements urbains (H/F)
# 451453  7096344                       Ingénieur d'Etudes VRD (H/F)
#
#                                               description  \
# 380     Nous recherchons pour une entreprise spécialis...
# ...
