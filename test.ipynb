# %%
import pandas as pd
import numpy as np
#from itables import init_notebook_mode
#import itables.options as opt

#init_notebook_mode(all_interactive=True)

# %%
from web.path import file

# %%
df = pd.read_csv(file, delimiter=',', encoding='utf-8')
# Out:
# C:\Users\gonze\AppData\Local\Temp\ipykernel_20828\1147848773.py:1: DtypeWarning: Columns (51,53,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, delimiter=',', encoding='utf-8')

# %%
df.dtypes
# Out:
# id                               object
# intitule                         object
# description                      object
# dateCreation                     object
# dateActualisation                object
# lieuTravail_libelle              object
# lieuTravail_latitude            float64
# lieuTravail_longitude           float64
# lieuTravail_codePostal          float64
# lieuTravail_commune              object
# romeCode                         object
# romeLibelle                      object
# appellationlibelle               object
# entreprise_nom                   object
# entreprise_entrepriseAdaptee       bool
# typeContrat                      object
# typeContratLibelle               object
# natureContrat                    object
# experienceExige                  object
# experienceLibelle                object
# alternance                         bool
# nombrePostes                      int64
# accessibleTH                       bool
# origineOffre_origine              int64
# origineOffre_urlOrigine          object
# origineOffre_partenaires         object
# entreprise_description           object
# dureeTravailLibelle              object
# dureeTravailLibelleConverti      object
# codeNAF                          object
# secteurActivite                 float64
# secteurActiviteLibelle           object
# salaire_libelle                  object
# salaire_commentaire              object
# qualificationCode               float64
# qualificationLibelle             object
# permis                           object
# competences                      object
# salaire_complement1              object
# salaire_complement2              object
# qualitesProfessionnelles         object
# formations                       object
# contact_nom                      object
# contact_coordonnees1             object
# contact_coordonnees2             object
# contact_coordonnees3             object
# agence_courriel                  object
# deplacementCode                 float64
# deplacementLibelle               object
# offresManqueCandidats            object
# contact_courriel                 object
# complementExercice               object
# experienceCommentaire            object
# entreprise_logo                  object
# langues                          object
# contact_urlPostulation           object
# entreprise_url                   object
# contact_telephone               float64
# conditionExercice                object
# agence_telephone                float64
# dtype: object

# %%
rom = ('M1805', 'M1403')

test = df.loc[df['romeCode'].str.startswith(rom)]
test
# Out:
#              id                                           intitule  \
# 380     3317313  Chargé(e)  du support  - Infrastructures des D...
# 578     3317313  Chargé(e)  du support  - Infrastructures des D...
# 766     3317313  Chargé(e)  du support  - Infrastructures des D...
# 900     3338741                             Analyste pricing (H/F)
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# ...         ...                                                ...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 455854  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456080  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456230  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456587  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 380     Nous recherchons pour une entreprise spécialis...
# 578     Nous recherchons pour une entreprise spécialis...
# 766     Nous recherchons pour une entreprise spécialis...
# 900     Description du poste :\nNotre entreprise\nTu e...
# 1006    France Travail et Dawan s'associent pour la mi...
# ...                                                   ...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 455854  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456080  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456230  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456587  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 380     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 578     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 766     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 900     2024-09-03T13:44:39.000Z  2024-11-20T03:12:05.000Z
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# ...                          ...                       ...
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 455854  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456080  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456230  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456587  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#            lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 380            976 - MAMOUDZOU            -12.797599              45.200869
# 578            976 - MAMOUDZOU            -12.797599              45.200869
# 766            976 - MAMOUDZOU            -12.797599              45.200869
# 900                 59 - LILLE             50.630993               3.045449
# 1006                 06 - NICE             43.712730               7.250920
# ...                        ...                   ...                    ...
# 455763  94 - CHARENTON LE PONT             48.823948               2.407129
# 455854  94 - CHARENTON LE PONT             48.823948               2.407129
# 456080  94 - CHARENTON LE PONT             48.823948               2.407129
# 456230  94 - CHARENTON LE PONT             48.823948               2.407129
# 456587  94 - CHARENTON LE PONT             48.823948               2.407129
#
#         lieuTravail_codePostal lieuTravail_commune  ...  \
# 380                    97600.0               97611  ...
# 578                    97600.0               97611  ...
# 766                    97600.0               97611  ...
# 900                    59000.0               59350  ...
# 1006                    6000.0               06088  ...
# ...                        ...                 ...  ...
# 455763                 94220.0               94018  ...
# 455854                 94220.0               94018  ...
# 456080                 94220.0               94018  ...
# 456230                 94220.0               94018  ...
# 456587                 94220.0               94018  ...
#
#                                          contact_courriel complementExercice  \
# 380                                                   NaN                NaN
# 578                                                   NaN                NaN
# 766                                                   NaN                NaN
# 900                                                   NaN                NaN
# 1006                                                  NaN                NaN
# ...                                                   ...                ...
# 455763  Pour postuler, utiliser le lien suivant : http...                NaN
# 455854  Pour postuler, utiliser le lien suivant : http...                NaN
# 456080  Pour postuler, utiliser le lien suivant : http...                NaN
# 456230  Pour postuler, utiliser le lien suivant : http...                NaN
# 456587  Pour postuler, utiliser le lien suivant : http...                NaN
#
#        experienceCommentaire entreprise_logo  langues  \
# 380                      NaN             NaN      NaN
# 578                      NaN             NaN      NaN
# 766                      NaN             NaN      NaN
# 900                      NaN             NaN      NaN
# 1006                     NaN             NaN      NaN
# ...                      ...             ...      ...
# 455763                   NaN             NaN      NaN
# 455854                   NaN             NaN      NaN
# 456080                   NaN             NaN      NaN
# 456230                   NaN             NaN      NaN
# 456587                   NaN             NaN      NaN
#
#                    contact_urlPostulation entreprise_url contact_telephone  \
# 380                                   NaN            NaN               NaN
# 578                                   NaN            NaN               NaN
# 766                                   NaN            NaN               NaN
# 900                                   NaN            NaN               NaN
# 1006    https://www.jehann.fr/recrutement            NaN               NaN
# ...                                   ...            ...               ...
# 455763                                NaN            NaN               NaN
# 455854                                NaN            NaN               NaN
# 456080                                NaN            NaN               NaN
# 456230                                NaN            NaN               NaN
# 456587                                NaN            NaN               NaN
#
#        conditionExercice agence_telephone
# 380                  NaN              NaN
# 578                  NaN              NaN
# 766                  NaN              NaN
# 900                  NaN              NaN
# 1006                 NaN              NaN
# ...                  ...              ...
# 455763               NaN              NaN
# 455854               NaN              NaN
# 456080               NaN              NaN
# 456230               NaN              NaN
# 456587               NaN              NaN
#
# [1435 rows x 60 columns]

# %%
# test2 = test.loc[test['romeLibelle'].str.contains('dév')]
# test3= test.loc[test['romeLibelle'].str.contains('Dév')]
# test4 = test.loc[test['romeLibelle'].str.contains('data')]
# test5 = test.loc[test['romeLibelle'].str.contains('Data')]

# combined_df = pd.concat([test2, test3, test4, test5])
# combined_df

# %%
combined_df = test.drop_duplicates(subset=['id'])

# %%
combined_df
# Out:
#              id                                           intitule  \
# 380     3317313  Chargé(e)  du support  - Infrastructures des D...
# 900     3338741                             Analyste pricing (H/F)
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# 1009    180MFWR                      Apprenti développeur IA (H/F)
# 2464    3479788       Chargé / Chargée d'études en marketing (H/F)
# ...         ...                                                ...
# 451214  7096326    Alternance Data Analyst - Aix-en-Provence (H/F)
# 451227  7096289                       Ingénieur d'Etudes VRD (H/F)
# 451237  7096253                          Chargé d'études VRD (H/F)
# 453255  7099010  Développeur angular F/H - Informatique de gest...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 380     Nous recherchons pour une entreprise spécialis...
# 900     Description du poste :\nNotre entreprise\nTu e...
# 1006    France Travail et Dawan s'associent pour la mi...
# 1009    France Travail et Dawan s'associent pour la mi...
# 2464    Embarquez avec Start People...CDI, CDD ou Inté...
# ...                                                   ...
# 451214  Description :\nL'ISCOD, spécialiste de la form...
# 451227  Société incontournable sur le marché du recrut...
# 451237  Société incontournable sur le marché du recrut...
# 453255  Descriptif du poste:\nL'équipe Dématérialisati...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 380     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 900     2024-09-03T13:44:39.000Z  2024-11-20T03:12:05.000Z
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# 1009    2024-09-03T16:47:21.998Z  2024-11-22T12:30:54.204Z
# 2464    2024-09-05T07:54:16.000Z  2024-11-16T07:37:38.000Z
# ...                          ...                       ...
# 451214  2024-11-06T10:16:37.000Z  2024-11-06T10:16:37.000Z
# 451227  2024-11-06T10:16:05.000Z  2024-11-06T10:16:05.000Z
# 451237  2024-11-06T10:15:42.000Z  2024-11-06T10:15:42.000Z
# 453255  2024-11-06T10:56:04.000Z  2024-11-06T12:53:13.000Z
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#            lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 380            976 - MAMOUDZOU            -12.797599              45.200869
# 900                 59 - LILLE             50.630993               3.045449
# 1006                 06 - NICE             43.712730               7.250920
# 1009         13 - MARSEILLE 02             43.315273               5.367338
# 2464            44 - CARQUEFOU             47.297116              -1.466824
# ...                        ...                   ...                    ...
# 451214    13 - AIX EN PROVENCE             43.541369               5.406124
# 451227            45 - ORLEANS             47.873507               1.911219
# 451237              74 - PASSY             45.925787               6.703807
# 453255              21 - DIJON             47.331848               5.033601
# 455763  94 - CHARENTON LE PONT             48.823948               2.407129
#
#         lieuTravail_codePostal lieuTravail_commune  ...  \
# 380                    97600.0               97611  ...
# 900                    59000.0               59350  ...
# 1006                    6000.0               06088  ...
# 1009                   13002.0               13202  ...
# 2464                   44470.0               44026  ...
# ...                        ...                 ...  ...
# 451214                 13080.0               13001  ...
# 451227                 45000.0               45234  ...
# 451237                 74190.0               74208  ...
# 453255                 21000.0               21231  ...
# 455763                 94220.0               94018  ...
#
#                                          contact_courriel complementExercice  \
# 380                                                   NaN                NaN
# 900                                                   NaN                NaN
# 1006                                                  NaN                NaN
# 1009                                                  NaN                NaN
# 2464                                                  NaN                NaN
# ...                                                   ...                ...
# 451214                                                NaN        Temps plein
# 451227                                                NaN        Temps plein
# 451237                                                NaN        Temps plein
# 453255                                                NaN                NaN
# 455763  Pour postuler, utiliser le lien suivant : http...                NaN
#
#        experienceCommentaire entreprise_logo  langues  \
# 380                      NaN             NaN      NaN
# 900                      NaN             NaN      NaN
# 1006                     NaN             NaN      NaN
# 1009                     NaN             NaN      NaN
# 2464                     NaN             NaN      NaN
# ...                      ...             ...      ...
# 451214                   NaN             NaN      NaN
# 451227                   NaN             NaN      NaN
# 451237                   NaN             NaN      NaN
# 453255                   NaN             NaN      NaN
# 455763                   NaN             NaN      NaN
#
#                    contact_urlPostulation entreprise_url contact_telephone  \
# 380                                   NaN            NaN               NaN
# 900                                   NaN            NaN               NaN
# 1006    https://www.jehann.fr/recrutement            NaN               NaN
# 1009    https://www.jehann.fr/recrutement            NaN               NaN
# 2464                                  NaN            NaN               NaN
# ...                                   ...            ...               ...
# 451214                                NaN            NaN               NaN
# 451227                                NaN            NaN               NaN
# 451237                                NaN            NaN               NaN
# 453255                                NaN            NaN               NaN
# 455763                                NaN            NaN               NaN
#
#        conditionExercice agence_telephone
# 380                  NaN              NaN
# 900                  NaN              NaN
# 1006                 NaN              NaN
# 1009                 NaN              NaN
# 2464                 NaN              NaN
# ...                  ...              ...
# 451214               NaN              NaN
# 451227               NaN              NaN
# 451237               NaN              NaN
# 453255               NaN              NaN
# 455763               NaN              NaN
#
# [665 rows x 60 columns]

# %%
new_df = pd.concat([combined_df['id'],combined_df['intitule'],combined_df['description'],combined_df['dateCreation'],combined_df['dateActualisation'],combined_df['lieuTravail_latitude'],combined_df['lieuTravail_longitude'],combined_df['lieuTravail_libelle'],combined_df['romeCode'],combined_df['typeContrat'],combined_df['experienceExige'],combined_df['alternance'],combined_df[ 'origineOffre_urlOrigine'],combined_df['dureeTravailLibelleConverti'],combined_df['competences'],combined_df['qualitesProfessionnelles'],combined_df['formations']], axis = 1)

# %%
new_df.shape
# Out:
# (665, 17)

# %%
new_df.fillna(value= 'Non Renseigné', inplace=True)
# Out:
# C:\Users\gonze\AppData\Local\Temp\ipykernel_20828\4210965673.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Non Renseigné' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   new_df.fillna(value= 'Non Renseigné', inplace=True)

# %%
# new_df.to_csv('france_travail_clean.csv', index=False)

# %%
print(new_df['competences'] != None)
# Out:
# 380       True
# 900       True
# 1006      True
# 1009      True
# 2464      True
#           ...
# 451214    True
# 451227    True
# 451237    True
# 453255    True
# 455763    True
# Name: competences, Length: 665, dtype: bool

# %%
str(new_df['competences'])
# Out:
# "380                                           Non Renseigné\n900                                           Non Renseigné\n1006      [{'code': '300688', 'libelle': 'Application we...\n1009      [{'code': '300688', 'libelle': 'Application we...\n2464                                          Non Renseigné\n                                ...                        \n451214                                        Non Renseigné\n451227                                        Non Renseigné\n451237                                        Non Renseigné\n453255                                        Non Renseigné\n455763    [{'code': '300688', 'libelle': 'Application we...\nName: competences, Length: 665, dtype: object"
