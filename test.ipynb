# %%
pip install numpy pandas
# Out:
# ...
#   Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/isalog/Brief11/france_travail.csv', delimiter=',', encoding ="utf-8" )
# Out:
# /tmp/ipykernel_23481/3713577409.py:1: DtypeWarning: Columns (51,53,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/isalog/Brief11/france_travail.csv', delimiter=',', encoding ="utf-8" )

# %%
df.head(2)
# Out:
#         id                                           intitule  \
# 0  3244435                            jardinier H/F - EC21126
# 1  3244427  agent développement social référent famille H/...
#
#                                          description  \
# 0  jardinier H/F - EC21126 Sous la responsabilité...
# 1  agent développement social référent famille H/...
#
#                dateCreation         dateActualisation  \
# 0  2024-09-01T02:51:53.000Z  2024-11-03T02:38:11.000Z
# 1  2024-09-01T02:51:30.000Z  2024-11-03T02:38:16.000Z
#
#           lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 0  78 - CONFLANS STE HONORINE             49.000025               2.099679
# 1                 95 - BEZONS             48.927132               2.214879
#
#    lieuTravail_codePostal lieuTravail_commune  ... contact_courriel  \
# 0                 78700.0               78172  ...              NaN
# 1                 95870.0               95063  ...              NaN
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'intitule', 'description', 'dateCreation', 'dateActualisation',
#        'lieuTravail_libelle', 'lieuTravail_latitude', 'lieuTravail_longitude',
#        'lieuTravail_codePostal', 'lieuTravail_commune', 'romeCode',
#        'romeLibelle', 'appellationlibelle', 'entreprise_nom',
#        'entreprise_entrepriseAdaptee', 'typeContrat', 'typeContratLibelle',
#        'natureContrat', 'experienceExige', 'experienceLibelle', 'alternance',
#        'nombrePostes', 'accessibleTH', 'origineOffre_origine',
#        'origineOffre_urlOrigine', 'origineOffre_partenaires',
#        'entreprise_description', 'dureeTravailLibelle',
#        'dureeTravailLibelleConverti', 'codeNAF', 'secteurActivite',
#        'secteurActiviteLibelle', 'salaire_libelle', 'salaire_commentaire',
#        'qualificationCode', 'qualificationLibelle', 'permis', 'competences',
#        'salaire_complement1', 'salaire_complement2',
#        'qualitesProfessionnelles', 'formations', 'contact_nom',
# ...

# %% [markdown]
# # Choix de 16 colonnes , pour travailler sur un premier fichier de données

# %%
data_column = pd.concat([df['id'],df['intitule'],df['description'],df['dateCreation'],df['dateActualisation'],df['lieuTravail_latitude'],df['lieuTravail_longitude'],df['lieuTravail_libelle'],df['romeCode'],df['typeContrat'],df['experienceExige'],df['alternance'],df[ 'origineOffre_urlOrigine'],df['dureeTravailLibelleConverti'],df['secteurActivite'],df['competences'],df['qualitesProfessionnelles'],df['formations']], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_column = pd.concat([df['id'],df['intitule'],df['description'],df['dateCreation'],df['dateActualisation'],df['lieuTravail_libelle'],df['romeCode'],df['typeContrat'],df['experienceExige'],df['alternance'],df[ 'origineOffre_urlOrigine'],df['dureeTravailLibelleConverti'],df['secteurActivite'],df['competences'],df['qualitesProfessionnelles'],df['formations']], axis = 1)
#
# NameError: name 'pd' is not defined

# %%
data_column.head(5)
# Out:
#         id                                           intitule  \
# 0  3244435                            jardinier H/F - EC21126
# 1  3244427  agent développement social référent famille H/...
# 2  3244363  chargé mission renouvellement urbain H/F - EC2...
# 3  3244340                  médecin généraliste H/F - EC20779
# 4  3244304          responsable administratif ve H/F - EC9293
#
#                                          description  \
# 0  jardinier H/F - EC21126 Sous la responsabilité...
# 1  agent développement social référent famille H/...
# 2  chargé mission renouvellement urbain H/F - EC2...
# 3  médecin généraliste H/F - EC20779 UNIQUE en so...
# 4  responsable administratif ve H/F - EC9293 Miss...
#
#                dateCreation         dateActualisation  \
# 0  2024-09-01T02:51:53.000Z  2024-11-03T02:38:11.000Z
# 1  2024-09-01T02:51:30.000Z  2024-11-03T02:38:16.000Z
# 2  2024-09-01T02:49:40.000Z  2024-11-01T02:54:16.000Z
# ...
