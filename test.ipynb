# %%
import pandas as pd
import numpy as np
# from itables import init_notebook_mode
# import itables.options as opt

# init_notebook_mode(all_interactive=True)

# %%
from path import file

# %%
df = pd.read_csv(file, delimiter=',', encoding='utf-8')
# Out:
# C:\Users\gonze\AppData\Local\Temp\ipykernel_8336\1147848773.py:1: DtypeWarning: Columns (51,53,56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, delimiter=',', encoding='utf-8')

# %%
df
# Out:
#              id                                           intitule  \
# 0       3244435                            jardinier H/F - EC21126
# 1       3244427  agent développement social référent famille H/...
# 2       3244363  chargé mission renouvellement urbain H/F - EC2...
# 3       3244340                  médecin généraliste H/F - EC20779
# 4       3244304          responsable administratif ve H/F - EC9293
# ...         ...                                                ...
# 458108  7103130                     Aide Auxiliaire H/F diplômé(e)
# 458109  7103129                       Responsable informatique H/F
# 458110  7103128                   CAP PETITE ENFANCE H/F en crèche
# 458111  7103127  Electromécanicien de maintenance industrielle H/F
# 458112  7103121                       Responsable informatique H/F
#
#                                               description  \
# 0       jardinier H/F - EC21126 Sous la responsabilité...
# 1       agent développement social référent famille H/...
# 2       chargé mission renouvellement urbain H/F - EC2...
# 3       médecin généraliste H/F - EC20779 UNIQUE en so...
# 4       responsable administratif ve H/F - EC9293 Miss...
# ...                                                   ...
# 458108  1er réseau d'agences de recrutement spécialisé...
# 458109  Le cabinet Lynx RH recherche un Responsable In...
# 458110  Envie de souplesse avec l'intérim ! Vitalis Mé...
# 458111  Vous êtes passionné par l'électromécanique et ...
# 458112  Le cabinet Lynx RH recherche un Responsable In...
#
#                     dateCreation         dateActualisation  \
# 0       2024-09-01T02:51:53.000Z  2024-11-03T02:38:11.000Z
# 1       2024-09-01T02:51:30.000Z  2024-11-03T02:38:16.000Z
# 2       2024-09-01T02:49:40.000Z  2024-11-01T02:54:16.000Z
# 3       2024-09-01T02:49:08.000Z  2024-11-22T02:45:19.000Z
# 4       2024-09-01T02:48:24.000Z  2024-11-01T03:00:32.000Z
# ...                          ...                       ...
# 458108  2024-11-06T11:54:05.000Z  2024-11-06T11:54:05.000Z
# 458109  2024-11-06T11:54:05.000Z  2024-11-06T11:54:05.000Z
# 458110  2024-11-06T11:54:05.000Z  2024-11-06T11:54:05.000Z
# 458111  2024-11-06T11:54:05.000Z  2024-11-08T21:42:12.000Z
# 458112  2024-11-06T11:54:03.000Z  2024-11-06T11:54:03.000Z
#
#                lieuTravail_libelle  lieuTravail_latitude  \
# 0       78 - CONFLANS STE HONORINE             49.000025
# 1                      95 - BEZONS             48.927132
# 2                  02 - ST QUENTIN             49.847398
# 3                    33 - ARCACHON             44.651462
# 4                     92 - BAGNEUX             48.797800
# ...                            ...                   ...
# 458108             78 - VERSAILLES             48.803019
# 458109                56 - LORIENT             47.750687
# 458110            78 - BOIS D ARCY             48.803102
# 458111      93 - NEUILLY SUR MARNE             48.864899
# 458112  50 - CHERBOURG EN COTENTIN             49.628684
#
#         lieuTravail_longitude  lieuTravail_codePostal lieuTravail_commune  \
# 0                    2.099679                 78700.0               78172
# 1                    2.214879                 95870.0               95063
# 2                    3.287450                  2100.0               02691
# 3                   -1.173981                 33120.0               33009
# 4                    2.310213                 92220.0               92007
# ...                       ...                     ...                 ...
# 458108               2.131319                 78000.0               78646
# 458109              -3.378425                 56100.0               56121
# 458110               2.024144                 78390.0               78073
# 458111               2.537373                 93330.0               93050
# 458112              -1.626864                 50100.0               50129
#
#         ... contact_courriel complementExercice experienceCommentaire  \
# 0       ...              NaN                NaN                   NaN
# 1       ...              NaN                NaN                   NaN
# 2       ...              NaN                NaN                   NaN
# 3       ...              NaN                NaN                   NaN
# 4       ...              NaN                NaN                   NaN
# ...     ...              ...                ...                   ...
# 458108  ...              NaN                NaN                   NaN
# 458109  ...              NaN                NaN                   NaN
# 458110  ...              NaN                NaN                   NaN
# 458111  ...              NaN                NaN                   NaN
# 458112  ...              NaN                NaN                   NaN
#
#        entreprise_logo  langues contact_urlPostulation entreprise_url  \
# 0                  NaN      NaN                    NaN            NaN
# 1                  NaN      NaN                    NaN            NaN
# 2                  NaN      NaN                    NaN            NaN
# 3                  NaN      NaN                    NaN            NaN
# 4                  NaN      NaN                    NaN            NaN
# ...                ...      ...                    ...            ...
# 458108             NaN      NaN                    NaN            NaN
# 458109             NaN      NaN                    NaN            NaN
# 458110             NaN      NaN                    NaN            NaN
# 458111             NaN      NaN                    NaN            NaN
# 458112             NaN      NaN                    NaN            NaN
#
#        contact_telephone conditionExercice agence_telephone
# 0                    NaN               NaN              NaN
# 1                    NaN               NaN              NaN
# 2                    NaN               NaN              NaN
# 3                    NaN               NaN              NaN
# 4                    NaN               NaN              NaN
# ...                  ...               ...              ...
# 458108               NaN               NaN              NaN
# 458109               NaN               NaN              NaN
# 458110               NaN               NaN              NaN
# 458111               NaN               NaN              NaN
# 458112               NaN               NaN              NaN
#
# [458113 rows x 60 columns]

# %%
df.dtypes
# Out:
# id                               object
# intitule                         object
# description                      object
# dateCreation                     object
# dateActualisation                object
# lieuTravail_libelle              object
# lieuTravail_latitude            float64
# lieuTravail_longitude           float64
# lieuTravail_codePostal          float64
# lieuTravail_commune              object
# romeCode                         object
# romeLibelle                      object
# appellationlibelle               object
# entreprise_nom                   object
# entreprise_entrepriseAdaptee       bool
# typeContrat                      object
# typeContratLibelle               object
# natureContrat                    object
# experienceExige                  object
# experienceLibelle                object
# alternance                         bool
# nombrePostes                      int64
# accessibleTH                       bool
# origineOffre_origine              int64
# origineOffre_urlOrigine          object
# origineOffre_partenaires         object
# entreprise_description           object
# dureeTravailLibelle              object
# dureeTravailLibelleConverti      object
# codeNAF                          object
# secteurActivite                 float64
# secteurActiviteLibelle           object
# salaire_libelle                  object
# salaire_commentaire              object
# qualificationCode               float64
# qualificationLibelle             object
# permis                           object
# competences                      object
# salaire_complement1              object
# salaire_complement2              object
# qualitesProfessionnelles         object
# formations                       object
# contact_nom                      object
# contact_coordonnees1             object
# contact_coordonnees2             object
# contact_coordonnees3             object
# agence_courriel                  object
# deplacementCode                 float64
# deplacementLibelle               object
# offresManqueCandidats            object
# contact_courriel                 object
# complementExercice               object
# experienceCommentaire            object
# entreprise_logo                  object
# langues                          object
# contact_urlPostulation           object
# entreprise_url                   object
# contact_telephone               float64
# conditionExercice                object
# agence_telephone                float64
# dtype: object

# %%
rom = ('M1805', 'M1403')

test = df.loc[df['romeCode'].str.startswith(rom)]
test
# Out:
#              id                                           intitule  \
# 380     3317313  Chargé(e)  du support  - Infrastructures des D...
# 578     3317313  Chargé(e)  du support  - Infrastructures des D...
# 766     3317313  Chargé(e)  du support  - Infrastructures des D...
# 900     3338741                             Analyste pricing (H/F)
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# ...         ...                                                ...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 455854  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456080  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456230  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456587  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 380     Nous recherchons pour une entreprise spécialis...
# 578     Nous recherchons pour une entreprise spécialis...
# 766     Nous recherchons pour une entreprise spécialis...
# 900     Description du poste :\nNotre entreprise\nTu e...
# 1006    France Travail et Dawan s'associent pour la mi...
# ...                                                   ...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 455854  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456080  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456230  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456587  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 380     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 578     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 766     2024-09-03T10:09:53.000Z  2024-09-03T10:09:53.000Z
# 900     2024-09-03T13:44:39.000Z  2024-11-20T03:12:05.000Z
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# ...                          ...                       ...
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 455854  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456080  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456230  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456587  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#            lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 380            976 - MAMOUDZOU            -12.797599              45.200869
# 578            976 - MAMOUDZOU            -12.797599              45.200869
# 766            976 - MAMOUDZOU            -12.797599              45.200869
# 900                 59 - LILLE             50.630993               3.045449
# 1006                 06 - NICE             43.712730               7.250920
# ...                        ...                   ...                    ...
# 455763  94 - CHARENTON LE PONT             48.823948               2.407129
# 455854  94 - CHARENTON LE PONT             48.823948               2.407129
# 456080  94 - CHARENTON LE PONT             48.823948               2.407129
# 456230  94 - CHARENTON LE PONT             48.823948               2.407129
# 456587  94 - CHARENTON LE PONT             48.823948               2.407129
#
#         lieuTravail_codePostal lieuTravail_commune  ...  \
# 380                    97600.0               97611  ...
# 578                    97600.0               97611  ...
# 766                    97600.0               97611  ...
# 900                    59000.0               59350  ...
# 1006                    6000.0               06088  ...
# ...                        ...                 ...  ...
# 455763                 94220.0               94018  ...
# 455854                 94220.0               94018  ...
# 456080                 94220.0               94018  ...
# 456230                 94220.0               94018  ...
# 456587                 94220.0               94018  ...
#
#                                          contact_courriel complementExercice  \
# 380                                                   NaN                NaN
# 578                                                   NaN                NaN
# 766                                                   NaN                NaN
# 900                                                   NaN                NaN
# 1006                                                  NaN                NaN
# ...                                                   ...                ...
# 455763  Pour postuler, utiliser le lien suivant : http...                NaN
# 455854  Pour postuler, utiliser le lien suivant : http...                NaN
# 456080  Pour postuler, utiliser le lien suivant : http...                NaN
# 456230  Pour postuler, utiliser le lien suivant : http...                NaN
# 456587  Pour postuler, utiliser le lien suivant : http...                NaN
#
#        experienceCommentaire entreprise_logo  langues  \
# 380                      NaN             NaN      NaN
# 578                      NaN             NaN      NaN
# 766                      NaN             NaN      NaN
# 900                      NaN             NaN      NaN
# 1006                     NaN             NaN      NaN
# ...                      ...             ...      ...
# 455763                   NaN             NaN      NaN
# 455854                   NaN             NaN      NaN
# 456080                   NaN             NaN      NaN
# 456230                   NaN             NaN      NaN
# 456587                   NaN             NaN      NaN
#
#                    contact_urlPostulation entreprise_url contact_telephone  \
# 380                                   NaN            NaN               NaN
# 578                                   NaN            NaN               NaN
# 766                                   NaN            NaN               NaN
# 900                                   NaN            NaN               NaN
# 1006    https://www.jehann.fr/recrutement            NaN               NaN
# ...                                   ...            ...               ...
# 455763                                NaN            NaN               NaN
# 455854                                NaN            NaN               NaN
# 456080                                NaN            NaN               NaN
# 456230                                NaN            NaN               NaN
# 456587                                NaN            NaN               NaN
#
#        conditionExercice agence_telephone
# 380                  NaN              NaN
# 578                  NaN              NaN
# 766                  NaN              NaN
# 900                  NaN              NaN
# 1006                 NaN              NaN
# ...                  ...              ...
# 455763               NaN              NaN
# 455854               NaN              NaN
# 456080               NaN              NaN
# 456230               NaN              NaN
# 456587               NaN              NaN
#
# [1435 rows x 60 columns]

# %%
test2 = test.loc[test['romeLibelle'].str.contains('dév')]
test3= test.loc[test['romeLibelle'].str.contains('Dév')]
test4 = test.loc[test['romeLibelle'].str.contains('data')]
test5 = test.loc[test['romeLibelle'].str.contains('Data')]

combined_df = pd.concat([test2, test3, test4, test5])
combined_df
# Out:
#              id                                           intitule  \
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# 1009    180MFWR                      Apprenti développeur IA (H/F)
# 3986    180RQXB                                 Développeur  (H/F)
# 5244    3651168                             Développeur JAVA (H/F)
# 5252    3650778                         Développeur JAVA JEE (H/F)
# ...         ...                                                ...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 455854  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456080  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456230  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
# 456587  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 1006    France Travail et Dawan s'associent pour la mi...
# 1009    France Travail et Dawan s'associent pour la mi...
# 3986    Vos missions:\nAu sein du département IT, en t...
# 5244    Description du poste :\nDans le cadre de nos a...
# 5252    Description du poste :\nDans le cadre de nos a...
# ...                                                   ...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 455854  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456080  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456230  Profil et prérequis \n\n- Vous êtes inscrit(e)...
# 456587  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# 1009    2024-09-03T16:47:21.998Z  2024-11-22T12:30:54.204Z
# 3986    2024-09-06T13:39:45.029Z  2024-11-08T09:56:09.515Z
# 5244    2024-09-07T11:44:56.000Z  2024-11-06T02:51:36.000Z
# 5252    2024-09-07T11:42:31.000Z  2024-11-06T02:47:39.000Z
# ...                          ...                       ...
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 455854  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456080  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456230  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
# 456587  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#            lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 1006                 06 - NICE             43.712730               7.250920
# 1009         13 - MARSEILLE 02             43.315273               5.367338
# 3986         83 - LE CASTELLET             43.211377               5.769568
# 5244               44 - NANTES             47.239367              -1.555335
# 5252             33 - BORDEAUX             44.851895              -0.587877
# ...                        ...                   ...                    ...
# 455763  94 - CHARENTON LE PONT             48.823948               2.407129
# 455854  94 - CHARENTON LE PONT             48.823948               2.407129
# 456080  94 - CHARENTON LE PONT             48.823948               2.407129
# 456230  94 - CHARENTON LE PONT             48.823948               2.407129
# 456587  94 - CHARENTON LE PONT             48.823948               2.407129
#
#         lieuTravail_codePostal lieuTravail_commune  ...  \
# 1006                    6000.0               06088  ...
# 1009                   13002.0               13202  ...
# 3986                   83330.0               83035  ...
# 5244                   44000.0               44109  ...
# 5252                   33000.0               33063  ...
# ...                        ...                 ...  ...
# 455763                 94220.0               94018  ...
# 455854                 94220.0               94018  ...
# 456080                 94220.0               94018  ...
# 456230                 94220.0               94018  ...
# 456587                 94220.0               94018  ...
#
#                                          contact_courriel complementExercice  \
# 1006                                                  NaN                NaN
# 1009                                                  NaN                NaN
# 3986                                                  NaN                NaN
# 5244                                                  NaN                NaN
# 5252                                                  NaN                NaN
# ...                                                   ...                ...
# 455763  Pour postuler, utiliser le lien suivant : http...                NaN
# 455854  Pour postuler, utiliser le lien suivant : http...                NaN
# 456080  Pour postuler, utiliser le lien suivant : http...                NaN
# 456230  Pour postuler, utiliser le lien suivant : http...                NaN
# 456587  Pour postuler, utiliser le lien suivant : http...                NaN
#
#        experienceCommentaire entreprise_logo  langues  \
# 1006                     NaN             NaN      NaN
# 1009                     NaN             NaN      NaN
# 3986                     NaN             NaN      NaN
# 5244                     NaN             NaN      NaN
# 5252                     NaN             NaN      NaN
# ...                      ...             ...      ...
# 455763                   NaN             NaN      NaN
# 455854                   NaN             NaN      NaN
# 456080                   NaN             NaN      NaN
# 456230                   NaN             NaN      NaN
# 456587                   NaN             NaN      NaN
#
#                    contact_urlPostulation entreprise_url contact_telephone  \
# 1006    https://www.jehann.fr/recrutement            NaN               NaN
# 1009    https://www.jehann.fr/recrutement            NaN               NaN
# 3986                                  NaN            NaN               NaN
# 5244                                  NaN            NaN               NaN
# 5252                                  NaN            NaN               NaN
# ...                                   ...            ...               ...
# 455763                                NaN            NaN               NaN
# 455854                                NaN            NaN               NaN
# 456080                                NaN            NaN               NaN
# 456230                                NaN            NaN               NaN
# 456587                                NaN            NaN               NaN
#
#        conditionExercice agence_telephone
# 1006                 NaN              NaN
# 1009                 NaN              NaN
# 3986                 NaN              NaN
# 5244                 NaN              NaN
# 5252                 NaN              NaN
# ...                  ...              ...
# 455763               NaN              NaN
# 455854               NaN              NaN
# 456080               NaN              NaN
# 456230               NaN              NaN
# 456587               NaN              NaN
#
# [701 rows x 60 columns]

# %%
combined_df = combined_df.drop_duplicates(subset=['id'])

# %%
combined_df
# Out:
#              id                                           intitule  \
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# 1009    180MFWR                      Apprenti développeur IA (H/F)
# 3986    180RQXB                                 Développeur  (H/F)
# 5244    3651168                             Développeur JAVA (H/F)
# 5252    3650778                         Développeur JAVA JEE (H/F)
# ...         ...                                                ...
# 444951  183SSRZ                             Développeur .NET (H/F)
# 446383  183STCM             Développeur Fullstack Senior H/F (H/F)
# 450634  7096150                              Analyste SOC N3 (H/F)
# 453255  7099010  Développeur angular F/H - Informatique de gest...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 1006    France Travail et Dawan s'associent pour la mi...
# 1009    France Travail et Dawan s'associent pour la mi...
# 3986    Vos missions:\nAu sein du département IT, en t...
# 5244    Description du poste :\nDans le cadre de nos a...
# 5252    Description du poste :\nDans le cadre de nos a...
# ...                                                   ...
# 444951  Depuis plus de 11 ans, SYNOVO GROUP se positio...
# 446383  Qui sommes-nous ?\nPrécurseur du Dossier patie...
# 450634  Synanto est une ESN à taille humaine avec un m...
# 453255  Descriptif du poste:\nL'équipe Dématérialisati...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# 1009    2024-09-03T16:47:21.998Z  2024-11-22T12:30:54.204Z
# 3986    2024-09-06T13:39:45.029Z  2024-11-08T09:56:09.515Z
# 5244    2024-09-07T11:44:56.000Z  2024-11-06T02:51:36.000Z
# 5252    2024-09-07T11:42:31.000Z  2024-11-06T02:47:39.000Z
# ...                          ...                       ...
# 444951  2024-11-06T09:38:54.131Z  2024-11-07T09:52:37.709Z
# 446383  2024-11-06T09:45:50.033Z  2024-11-06T09:45:50.569Z
# 450634  2024-11-06T10:14:23.000Z  2024-11-06T10:14:23.000Z
# 453255  2024-11-06T10:56:04.000Z  2024-11-06T12:53:13.000Z
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#            lieuTravail_libelle  lieuTravail_latitude  lieuTravail_longitude  \
# 1006                 06 - NICE             43.712730               7.250920
# 1009         13 - MARSEILLE 02             43.315273               5.367338
# 3986         83 - LE CASTELLET             43.211377               5.769568
# 5244               44 - NANTES             47.239367              -1.555335
# 5252             33 - BORDEAUX             44.851895              -0.587877
# ...                        ...                   ...                    ...
# 444951         67 - STRASBOURG             48.579831               7.761454
# 446383        34 - MONTPELLIER             43.610476               3.870480
# 450634               06 - NICE             43.713012               7.250987
# 453255              21 - DIJON             47.331848               5.033601
# 455763  94 - CHARENTON LE PONT             48.823948               2.407129
#
#         lieuTravail_codePostal lieuTravail_commune  ...  \
# 1006                    6000.0               06088  ...
# 1009                   13002.0               13202  ...
# 3986                   83330.0               83035  ...
# 5244                   44000.0               44109  ...
# 5252                   33000.0               33063  ...
# ...                        ...                 ...  ...
# 444951                 67000.0               67482  ...
# 446383                 34000.0               34172  ...
# 450634                  6000.0               06088  ...
# 453255                 21000.0               21231  ...
# 455763                 94220.0               94018  ...
#
#                                          contact_courriel complementExercice  \
# 1006                                                  NaN                NaN
# 1009                                                  NaN                NaN
# 3986                                                  NaN                NaN
# 5244                                                  NaN                NaN
# 5252                                                  NaN                NaN
# ...                                                   ...                ...
# 444951  Pour postuler, utiliser le lien suivant : http...                NaN
# 446383                                                NaN                NaN
# 450634                                                NaN        Temps plein
# 453255                                                NaN                NaN
# 455763  Pour postuler, utiliser le lien suivant : http...                NaN
#
#        experienceCommentaire entreprise_logo  langues  \
# 1006                     NaN             NaN      NaN
# 1009                     NaN             NaN      NaN
# 3986                     NaN             NaN      NaN
# 5244                     NaN             NaN      NaN
# 5252                     NaN             NaN      NaN
# ...                      ...             ...      ...
# 444951                   NaN             NaN      NaN
# 446383                   NaN             NaN      NaN
# 450634                   NaN             NaN      NaN
# 453255                   NaN             NaN      NaN
# 455763                   NaN             NaN      NaN
#
#                    contact_urlPostulation entreprise_url contact_telephone  \
# 1006    https://www.jehann.fr/recrutement            NaN               NaN
# 1009    https://www.jehann.fr/recrutement            NaN               NaN
# 3986                                  NaN            NaN               NaN
# 5244                                  NaN            NaN               NaN
# 5252                                  NaN            NaN               NaN
# ...                                   ...            ...               ...
# 444951                                NaN            NaN               NaN
# 446383                                NaN            NaN               NaN
# 450634                                NaN            NaN               NaN
# 453255                                NaN            NaN               NaN
# 455763                                NaN            NaN               NaN
#
#        conditionExercice agence_telephone
# 1006                 NaN              NaN
# 1009                 NaN              NaN
# 3986                 NaN              NaN
# 5244                 NaN              NaN
# 5252                 NaN              NaN
# ...                  ...              ...
# 444951               NaN              NaN
# 446383               NaN              NaN
# 450634               NaN              NaN
# 453255               NaN              NaN
# 455763               NaN              NaN
#
# [338 rows x 60 columns]

# %%
new_df = pd.concat([combined_df['id'],combined_df['intitule'],combined_df['description'],combined_df['dateCreation'],combined_df['dateActualisation'],combined_df['lieuTravail_latitude'],combined_df['lieuTravail_longitude'],combined_df['lieuTravail_libelle'],combined_df['romeCode'],combined_df['typeContrat'],combined_df['experienceExige'],combined_df['alternance'],combined_df[ 'origineOffre_urlOrigine'],combined_df['dureeTravailLibelleConverti'],combined_df['secteurActivite'],combined_df['competences'],combined_df['qualitesProfessionnelles'],combined_df['formations']], axis = 1)

# %%
new_df.shape
# Out:
# (338, 18)

# %%
new_df
# Out:
#              id                                           intitule  \
# 1006    180MGNY                      Apprenti développeur IA (H/F)
# 1009    180MFWR                      Apprenti développeur IA (H/F)
# 3986    180RQXB                                 Développeur  (H/F)
# 5244    3651168                             Développeur JAVA (H/F)
# 5252    3650778                         Développeur JAVA JEE (H/F)
# ...         ...                                                ...
# 444951  183SSRZ                             Développeur .NET (H/F)
# 446383  183STCM             Développeur Fullstack Senior H/F (H/F)
# 450634  7096150                              Analyste SOC N3 (H/F)
# 453255  7099010  Développeur angular F/H - Informatique de gest...
# 455763  183SYNR  Développeur Microsoft  DotNet/Mainframe (CDI) ...
#
#                                               description  \
# 1006    France Travail et Dawan s'associent pour la mi...
# 1009    France Travail et Dawan s'associent pour la mi...
# 3986    Vos missions:\nAu sein du département IT, en t...
# 5244    Description du poste :\nDans le cadre de nos a...
# 5252    Description du poste :\nDans le cadre de nos a...
# ...                                                   ...
# 444951  Depuis plus de 11 ans, SYNOVO GROUP se positio...
# 446383  Qui sommes-nous ?\nPrécurseur du Dossier patie...
# 450634  Synanto est une ESN à taille humaine avec un m...
# 453255  Descriptif du poste:\nL'équipe Dématérialisati...
# 455763  Profil et prérequis \n\n- Vous êtes inscrit(e)...
#
#                     dateCreation         dateActualisation  \
# 1006    2024-09-03T16:58:39.792Z  2024-11-22T12:31:28.887Z
# 1009    2024-09-03T16:47:21.998Z  2024-11-22T12:30:54.204Z
# 3986    2024-09-06T13:39:45.029Z  2024-11-08T09:56:09.515Z
# 5244    2024-09-07T11:44:56.000Z  2024-11-06T02:51:36.000Z
# 5252    2024-09-07T11:42:31.000Z  2024-11-06T02:47:39.000Z
# ...                          ...                       ...
# 444951  2024-11-06T09:38:54.131Z  2024-11-07T09:52:37.709Z
# 446383  2024-11-06T09:45:50.033Z  2024-11-06T09:45:50.569Z
# 450634  2024-11-06T10:14:23.000Z  2024-11-06T10:14:23.000Z
# 453255  2024-11-06T10:56:04.000Z  2024-11-06T12:53:13.000Z
# 455763  2024-11-06T11:04:50.933Z  2024-11-07T09:22:02.638Z
#
#         lieuTravail_latitude  lieuTravail_longitude     lieuTravail_libelle  \
# 1006               43.712730               7.250920               06 - NICE
# 1009               43.315273               5.367338       13 - MARSEILLE 02
# 3986               43.211377               5.769568       83 - LE CASTELLET
# 5244               47.239367              -1.555335             44 - NANTES
# 5252               44.851895              -0.587877           33 - BORDEAUX
# ...                      ...                    ...                     ...
# 444951             48.579831               7.761454         67 - STRASBOURG
# 446383             43.610476               3.870480        34 - MONTPELLIER
# 450634             43.713012               7.250987               06 - NICE
# 453255             47.331848               5.033601              21 - DIJON
# 455763             48.823948               2.407129  94 - CHARENTON LE PONT
#
#        romeCode typeContrat experienceExige  alternance  \
# 1006      M1805         CDD               D        True
# 1009      M1805         CDD               D        True
# 3986      M1805         CDI               E       False
# 5244      M1805         LIB               E       False
# 5252      M1805         LIB               E       False
# ...         ...         ...             ...         ...
# 444951    M1805         CDI               E       False
# 446383    M1805         CDI               E       False
# 450634    M1805         CDI               E       False
# 453255    M1805         CDI               E       False
# 455763    M1805         CDI               D       False
#
#                                   origineOffre_urlOrigine  \
# 1006    https://candidat.francetravail.fr/offres/reche...
# 1009    https://candidat.francetravail.fr/offres/reche...
# 3986    https://candidat.francetravail.fr/offres/reche...
# 5244    https://candidat.francetravail.fr/offres/reche...
# 5252    https://candidat.francetravail.fr/offres/reche...
# ...                                                   ...
# 444951  https://candidat.francetravail.fr/offres/reche...
# 446383  https://candidat.francetravail.fr/offres/reche...
# 450634  https://candidat.francetravail.fr/offres/reche...
# 453255  https://candidat.francetravail.fr/offres/reche...
# 455763  https://candidat.francetravail.fr/offres/reche...
#
#        dureeTravailLibelleConverti  secteurActivite  \
# 1006                   Temps plein             62.0
# 1009                   Temps plein             62.0
# 3986                   Temps plein             93.0
# 5244                           NaN              NaN
# 5252                           NaN              NaN
# ...                            ...              ...
# 444951                 Temps plein             58.0
# 446383                 Temps plein             58.0
# 450634                         NaN              NaN
# 453255                         NaN             62.0
# 455763                 Temps plein             62.0
#
#                                               competences  \
# 1006    [{'code': '300688', 'libelle': 'Application we...
# 1009    [{'code': '300688', 'libelle': 'Application we...
# 3986    [{'code': '300688', 'libelle': 'Application we...
# 5244                                                  NaN
# 5252                                                  NaN
# ...                                                   ...
# 444951  [{'code': '300688', 'libelle': 'Application we...
# 446383  [{'code': '300688', 'libelle': 'Application we...
# 450634                                                NaN
# 453255                                                NaN
# 455763  [{'code': '300688', 'libelle': 'Application we...
#
#                                  qualitesProfessionnelles  \
# 1006    [{'libelle': "Faire preuve d'autonomie", 'desc...
# 1009    [{'libelle': "Faire preuve d'autonomie", 'desc...
# 3986                                                  NaN
# 5244                                                  NaN
# 5252                                                  NaN
# ...                                                   ...
# 444951                                                NaN
# 446383  [{'libelle': 'Faire preuve de rigueur et de pr...
# 450634                                                NaN
# 453255                                                NaN
# 455763                                                NaN
#
#                                                formations
# 1006                                                  NaN
# 1009                                                  NaN
# 3986    [{'codeFormation': '24231', 'domaineLibelle': ...
# 5244                                                  NaN
# 5252                                                  NaN
# ...                                                   ...
# 444951  [{'codeFormation': '30854', 'domaineLibelle': ...
# 446383                                                NaN
# 450634                                                NaN
# 453255                                                NaN
# 455763                                                NaN
#
# [338 rows x 18 columns]

# %%
new_df.isna()
# Out:
#            id  intitule  description  dateCreation  dateActualisation  \
# 1006    False     False        False         False              False
# 1009    False     False        False         False              False
# 3986    False     False        False         False              False
# 5244    False     False        False         False              False
# 5252    False     False        False         False              False
# ...       ...       ...          ...           ...                ...
# 444951  False     False        False         False              False
# 446383  False     False        False         False              False
# 450634  False     False        False         False              False
# 453255  False     False        False         False              False
# 455763  False     False        False         False              False
#
#         lieuTravail_latitude  lieuTravail_longitude  lieuTravail_libelle  \
# 1006                   False                  False                False
# 1009                   False                  False                False
# 3986                   False                  False                False
# 5244                   False                  False                False
# 5252                   False                  False                False
# ...                      ...                    ...                  ...
# 444951                 False                  False                False
# 446383                 False                  False                False
# 450634                 False                  False                False
# 453255                 False                  False                False
# 455763                 False                  False                False
#
#         romeCode  typeContrat  experienceExige  alternance  \
# 1006       False        False            False       False
# 1009       False        False            False       False
# 3986       False        False            False       False
# 5244       False        False            False       False
# 5252       False        False            False       False
# ...          ...          ...              ...         ...
# 444951     False        False            False       False
# 446383     False        False            False       False
# 450634     False        False            False       False
# 453255     False        False            False       False
# 455763     False        False            False       False
#
#         origineOffre_urlOrigine  dureeTravailLibelleConverti  secteurActivite  \
# 1006                      False                        False            False
# 1009                      False                        False            False
# 3986                      False                        False            False
# 5244                      False                         True             True
# 5252                      False                         True             True
# ...                         ...                          ...              ...
# 444951                    False                        False            False
# 446383                    False                        False            False
# 450634                    False                         True             True
# 453255                    False                         True            False
# 455763                    False                        False            False
#
#         competences  qualitesProfessionnelles  formations
# 1006          False                     False        True
# 1009          False                     False        True
# 3986          False                      True       False
# 5244           True                      True        True
# 5252           True                      True        True
# ...             ...                       ...         ...
# 444951        False                      True       False
# 446383        False                     False        True
# 450634         True                      True        True
# 453255         True                      True        True
# 455763        False                      True        True
#
# [338 rows x 18 columns]

# %%
new_df.fillna(value = 'Non Renseigné', inplace=True)
# Out:
# C:\Users\gonze\AppData\Local\Temp\ipykernel_8336\1391695781.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Non Renseigné' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   new_df.fillna(value = 'Non Renseigné', inplace=True)

# %%
new_df.to_csv('france_travail_clean.csv', index=False)
